# %% [markdown]
# # London Bike sharing demand predicton
# ## Which machine learning algorithm performs better in prediction of bike sharing demand in London?.

# %% [markdown]
# ## 1. Introduction
# In recent years, sharing bike systems have garnered increased attention as an emerging mode of transportation. Shaheen et al. (Susan, 2010) summarized the advantages of sharing bikes, highlighting their flexible mobility and contribution to emission reduction. Building upon this, Bullock et al. (Craig Bullock, Finbarr Brereton and Sive Bailey, 2017) further dissected the private and public benefits introduced by sharing bike systems.
#
# Hence, the research aims to integrate diverse approaches to predict the hourly total demand for shared bicycles in London. It will systematically evaluate and compare the efficacy of these algorithms to ascertain their effectiveness in demand prediction.

# %% [markdown]
# ## 2. Literature Review
# Prior research conducted by Rixey et al. (R. Alexander Rixey, 2013) on three diverse cities in the USA and Faghih et al. (Ahmadreza Faghih-Imani, Naveen Eluru, Ahmed M. El-Geneidy, Michael Rabbat and Usama Haq, 2014) on Montreal demonstrated the efficacy of regression analysis in predicting sharing bike flow. These studies underscored the significance of forecasting sharing bike flow to optimize existing systems and served as references for cities contemplating the establishment of such systems.
#
# In recent years, various studies have explored more complicated regression methodologies for predicting shared bicycle demand, employing a range of algorithms. For instance, Gu and Lin applied multiple linear regression and random forests (Gu, 2023), Schimohr et al. adopted XGBoost (Schimohr, 2023). While existing studies have individually demonstrated the effectiveness of various algorithms in addressing prediction problems, there is a notable lack of studies conducting extensive comparisons across a range of algorithms. Identifying the algorithm that offers the best performance and highest prediction efficiency among a diverse set of algorithms presents a valuable research opportunity.

# %% [markdown]
# ## 3. Research Question
# The research aims to integrate diverse approaches, OLS, RF and XGB to predict the hourly total demand for shared bicycles in London. It will systematically evaluate and compare the efficacy of these algorithms, focusing on the question, 'Which machine learning algorithm performs better in prediction of bike sharing demand in London?'

# %% [markdown]
# ### Import Libs

# %%
import warnings
import sklearn.exceptions
warnings.filterwarnings("ignore", category=sklearn.exceptions.ConvergenceWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, TimeSeriesSplit, GridSearchCV,cross_val_score 
from sklearn import preprocessing
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import mean_absolute_error,r2_score, mean_squared_log_error,mean_squared_error, make_scorer
import time
from scipy import stats
from scipy.stats import norm, skew, kurtosis


np.random.seed(42)
np.random.RandomState(42)
# Out:
# RandomState(MT19937) at 0x7F8CAF940140

# %% [markdown]
# ## 4. Data presentation
# The data is gathered from 3 sources:
#  * https://cycling.data.tfl.gov.uk/ *'Contains OS data © Crown copyright and database rights 2016' and Geomni UK Map data © and database rights [2019] 'Powered by TfL Open Data'* - Bike sharing usage dataset
#  * https://freemeteo.com - weather data
#  * https://www.gov.uk/bank-holidays - official bank holidays in Lond
#
# The data is grouped by hour and merged is published on "Kaggle" -
# https://www.kaggle.com/hmavrodiev/london-bike-sharing-dataseton.
#
# ### Metadata:
# "timestamp" - *timestamp field for grouping the data*
# "cnt" - *the count of a new bike shares*
# "t1" - *real temperature in C*
# "t2" - *temperature in C "feels like"*
# "hum" - *humidity in percentage*
# "wind_speed" - *wind speed in km/h*
# "weather_code" - *category of the weather*
# "is_holiday" - *boolean field - 1 holiday / 0 non holiday*
# "is_weekend" - *boolean field - 1 if the day is weekend*
# "season" - *category field meteorological seasons: 0-spring ; 1-summer; 2-fall;3-winter.*
#
# Weather Code category description:
# * 1 = Clear
# * 2 = Scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain / light rain shower / light rain
# * 10 = Rain with thunderstorm
# * 26 = Snowfall
# * 94 = Freezing fog

# %% [markdown]
# ### 4.1 Import Dataset

# %%
bike = pd.DataFrame(pd.read_csv("data/london_merged.csv"))
bike.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
bike.info()
print(bike.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB
# (17414, 10)

# %%
bike.describe()
# Out:
#                 cnt            t1            t2           hum    wind_speed  \
# count  17414.000000  17414.000000  17414.000000  17414.000000  17414.000000
# mean    1143.101642     12.468091     11.520836     72.324954     15.913063
# std     1085.108068      5.571818      6.615145     14.313186      7.894570
# min        0.000000     -1.500000     -6.000000     20.500000      0.000000
# 25%      257.000000      8.000000      6.000000     63.000000     10.000000
# 50%      844.000000     12.500000     12.500000     74.500000     15.000000
# 75%     1671.750000     16.000000     16.000000     83.000000     20.500000
# max     7860.000000     34.000000     34.000000    100.000000     56.500000
#
#        weather_code    is_holiday    is_weekend        season
# count  17414.000000  17414.000000  17414.000000  17414.000000
# mean       2.722752      0.022051      0.285403      1.492075
# std        2.341163      0.146854      0.451619      1.118911
# ...

# %% [markdown]
# ### 4.2 Check Missing values
# The following result indicates no missing values in the dataset.

# %%
round(100*(bike.isnull().sum()/len(bike)), 2).sort_values(ascending=False)
round((bike.isnull().sum(axis=1)/len(bike))*100,2).sort_values(ascending=False)
# Out:
# 0        0.0
# 11607    0.0
# 11613    0.0
# 11612    0.0
# 11611    0.0
#         ...
# 5810     0.0
# 5811     0.0
# 5812     0.0
# 5813     0.0
# 17413    0.0
# Length: 17414, dtype: float64

# %% [markdown]
# ### 4.3 Data Preprocess: Timestamp Division

# %%
rawData=bike.copy()
bike["timestamp"] = pd.to_datetime(bike["timestamp"])
bike = bike.set_index("timestamp")

bike.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %%
bike["hour"] = bike.index.hour
bike["day_of_month"] = bike.index.day
bike["day_of_week"]  = bike.index.dayofweek
bike["month"] = bike.index.month
bike['year'] = bike.index.year

bike.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season  hour  day_of_month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0     0             4
# 2015-01-04 01:00:00         0.0         1.0     3.0     1             4
# 2015-01-04 02:00:00         0.0         1.0     3.0     2             4
# 2015-01-04 03:00:00         0.0         1.0     3.0     3             4
# 2015-01-04 04:00:00         0.0         1.0     3.0     4             4
#
#                      day_of_week  month  year
# timestamp
# ...

# %% [markdown]
# ### 4.4 Data Overview:
#
# #### 4.4.1 Count of bike shares per month
# The following three plots show the bike shares across the time.

# %%
plt.figure(figsize=(15, 7))
ax = sns.lineplot(x=bike.index, y=bike.cnt,data=bike)
ax.set_title("Count of bike shares VS Date", fontsize=25)
ax.set_xlabel("Date", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.show()

# %%
bike_by_month = bike.resample("M").sum()
plt.figure(figsize=(16,6))
ax = sns.lineplot(data=bike_by_month,x=bike_by_month.index,y=bike_by_month.cnt)
ax.set_title("Count of bike shares per Month", fontsize=25)
ax.set_xlabel("Month", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.show()

# %%
bike_by_week = bike.resample("D").sum()
plt.figure(figsize=(16,6))
ax = sns.lineplot(data=bike_by_week,x=bike_by_week.index,y=bike_by_week.cnt)
ax.set_title("Count of bike shares per Day", fontsize=25)
ax.set_xlabel("Day", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(16,6))
ax = sns.pointplot(data=bike,hue=bike.season,y=bike.cnt,x=bike.month)
ax.set_title("Count of bike shares per Season", fontsize=25)
ax.set_xlabel("Month", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.show()

# %% [markdown]
# All three plots above show a noticeable dip in shares around the winter period of each year. By contrast bike shares are increasing towards the summer months.

# %% [markdown]
# #### 4.4.2 Count of bike shares in a week
# The following plot is a timespan from one week.

# %%
plt.figure(figsize=(16, 6))
ax = sns.pointplot(x='day_of_week', y='cnt',data=bike)
ax.set_title("Count of bike shares in a Week", fontsize=25)
ax.set_xlabel("Day of the week", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.show()

# %% [markdown]
# It's obvious that less bikes are rented within the weekend.

# %% [markdown]
# #### 4.4.3 Count of bike shares in a day

# %%
plt.figure(figsize=(16, 6))
ax = sns.pointplot(x='hour', y='cnt',hue='is_holiday',data=bike)
ax.set_title("Count of bike shares per hour in a day", fontsize=25)
ax.set_xlabel("Hour of they day", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.show()

# %% [markdown]
# On a normal day most bikes are rented within the rush hour peaks while on a holiday this clearly changes, the rush hour peaks are not present and most bikes ar rented in the afternoon.
#
# It can be concluded that's there a distinct difference in shares when it's not a working day.

# %% [markdown]
# #### 4.4.4 Count of bike shares related to temperature

# %%
plt.figure(figsize=(20,10))
ax = sns.pointplot(x='t1', y='cnt',data=bike)
ax.set_title("Count of bike shares VS Real Temperature", fontsize=25)
ax.set_xlabel("Real tmperature (°C)", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.locator_params(axis='x', nbins=10)

# %%
plt.figure(figsize=(20,10))
ax = sns.pointplot(x='t2', y='cnt',data=bike)
ax.set_title("Count of bike shares VS Feeling Temperature", fontsize=25)
ax.set_xlabel("Feeling temperature (°C)", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.locator_params(axis='x', nbins=10)
plt.show()

# %% [markdown]
# More bikes rent appears when the temperature is high.

# %% [markdown]
# #### 4.4.5 Count of bike shares related to the humidity

# %%
plt.figure(figsize=(20,10))

ax = sns.pointplot(x='hum', y='cnt',data=bike)
ax.set_title("Count of bike shares VS Humidity", fontsize=25)
ax.set_xlabel("Humidity (%)", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.locator_params(axis='x', nbins=10)
plt.show()

# %% [markdown]
# An increase in humidity results in a decrease of the bikes shared.

# %% [markdown]
# #### 4.4.6 Count of bike shares related to the windspeed

# %%
plt.figure(figsize=(20,10))

ax = sns.pointplot(x='wind_speed', y='cnt',data=bike)
ax.set_title("Count of bike shares VS Windspeed", fontsize=25)
ax.set_xlabel("Windspeed (km/h)", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.locator_params(axis='x', nbins=10)
plt.show()

# %% [markdown]
# There is small peak when the windspeed is at around 25 km/h.

# %% [markdown]
# #### 4.4.7 Count of bike shares related to the weather

# %%
plt.figure(figsize=(16,6))
ax = sns.histplot(data=bike,y=bike.cnt,x=bike.weather_code)
ax.set_title("Count of bike shares VS Weather", fontsize=25)
ax.set_xlabel("Weather code", fontsize=20)
ax.set_ylabel('Count of bike shares', fontsize=20)
plt.show()

# %% [markdown]
# When the weather is good (1,2,3,4,7) more bikes are rented then when the weather is bad (10,26).

# %% [markdown]
# #### 4.4.8 Feature Correlation

# %%
plt.figure(figsize=(16,6))
sns.heatmap(bike.corr(),cmap="YlGnBu",square=True,linewidths=.5,center=0)
# Out:
# <Axes: >

# %% [markdown]
# #### 4.4.9 Feature Distribution Analysis

# %%
def plot_distribution(bike,columns,**kwargs ):
    fig, axes = plt.subplots(ncols=len(columns),figsize=(30,5))
    for axs, col in zip(axes, columns):
        sns.distplot(bike[col], ax=axs,**kwargs)
    fig.suptitle('Feature distribution')
    
plot_distribution(bike,bike.drop(['weather_code','is_holiday','is_weekend','season','hour','day_of_month','day_of_week','month','year'],axis=1).columns, kde=False)
# Out:
# /tmp/ipykernel_1900/3715611989.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bike[col], ax=axs,**kwargs)

# %% [markdown]
# From the above districution plots, the distribution of 'cnt' column does not looks like Gaussian. It is more similar to Exponential-logarithmic distribution and it's highly skewed at the left.
#
# The distribution of other columns looks good, doesn't need any transformations.

# %% [markdown]
# ## 5. Methodology

# %% [markdown]
# ### 5.1 Feature Engineering
# As mentioned above, methods that transform the target variable to more Gaussian distribution is needed as the transformation reduces the variance in the data, helps to reduce the effect of outliers and support further residuals analysis.
#
# The column 'count_log' represents the transformed of 'cnt' column with log1p numpy function.

# %%
bike['count_log'] = np.log1p(bike['cnt'])
plot_distribution(bike,bike.drop(['weather_code','is_holiday','is_weekend','season','hour','day_of_month','day_of_week','month','year'],axis=1).columns, kde=False)
# Out:
# /tmp/ipykernel_1900/3715611989.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(bike[col], ax=axs,**kwargs)

# %% [markdown]
# The column 'is_holida' looks highly imbalanced, so grouped with "is_weekend" in a new column to represent a working day or not.
#
# The figure in 4.4.3 shows that the daylight might be a crucial factor that is creating count differences of the data. A new column 'is_night' is created that is approximately separating the data.

# %%
bike['is_non_workday'] = bike['is_holiday'] + bike['is_weekend']
bike = bike.drop(['is_holiday','is_weekend'],axis=1)
bike['is_night'] = 0
bike.loc[(bike['hour'] < 8) | (bike['hour'] > 20), 'is_night'] = 1

bike.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  season  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0     3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0     3.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0     3.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0     3.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0     3.0
#
#                      hour  day_of_month  day_of_week  month  year  count_log  \
# timestamp
# 2015-01-04 00:00:00     0             4            6      1  2015   5.209486
# 2015-01-04 01:00:00     1             4            6      1  2015   4.934474
# 2015-01-04 02:00:00     2             4            6      1  2015   4.905275
# 2015-01-04 03:00:00     3             4            6      1  2015   4.290459
# 2015-01-04 04:00:00     4             4            6      1  2015   3.871201
#
# ...

# %% [markdown]
# After splitting the timestamp column, it becomes evident that the hour and month attributes significantly influence fluctuations in bicycle usage and exhibit clear periodicity. Consequently, these attributes are encoded using sine and cosine functions to enable the model to more effectively capture temporal periodicity.

# %%
def time_encode(df, column, max_value):  
    df[column + '_sin'] = np.sin(2 * np.pi * df[column] / max_value)
    df[column + '_cos'] = np.cos(2 * np.pi * df[column] / max_value)
    return df

bike_time_encode=bike.copy()
time_encode(bike_time_encode,'hour',23)
time_encode(bike_time_encode,'month',12)

bike_time_encode.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  season  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0     3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0     3.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0     3.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0     3.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0     3.0
#
#                      hour  day_of_month  day_of_week  month  year  count_log  \
# timestamp
# 2015-01-04 00:00:00     0             4            6      1  2015   5.209486
# 2015-01-04 01:00:00     1             4            6      1  2015   4.934474
# 2015-01-04 02:00:00     2             4            6      1  2015   4.905275
# 2015-01-04 03:00:00     3             4            6      1  2015   4.290459
# 2015-01-04 04:00:00     4             4            6      1  2015   3.871201
#
# ...

# %%
df = bike_time_encode.reset_index(drop=True, inplace=False)
X = df.drop(['count_log'], axis=1)
y = df['count_log']
scaler_x = preprocessing.MinMaxScaler()
X =  pd.DataFrame(scaler_x.fit_transform(X), columns = X.columns)

# %% [markdown]
# ### 5.2 Split Dataset
#
# The dataset is separated to train and test sets, also the training set will be splitted for time series cross validation. Noticing that there is no shuffling in the data and simulates the case when the testing set is in the future. The algorithm is always trained with past data and validated with future data.

# %% [markdown]
# <img src="data:image/png;base64,..." width="480">

# %%
def df_split(df,train_percent):
    split_index = int(train_percent * len(df))
    train = df.iloc[:split_index]
    test = df.iloc[split_index:]
    return train,test
    
X_train,X_test = df_split(X,0.7)
y_train,y_test = df_split(y,0.7)

# %% [markdown]
# ### 5.3 Scoring Metric
#
# The Root Mean Squared Logarithmic Error (RMSLE) serves as a scoring function to assess differences between predicted and actual values in contexts such as competitions and predictive modeling. This metric is particularly useful in datasets that span a broad range of values—from very large to very small—making it ideal when outliers could disproportionately skew accuracy assessments. RMSLE is favored because it minimizes the influence of outliers by focusing on percentage errors rather than absolute differences, thereby reducing sensitivity to large errors at higher value scales and increasing it at lower value scales. This quality allows RMSLE to more accurately reflect proportional inaccuracies in predictions, rather than being biased by large numerical errors.
#
# Furthermore, RMSLE places a greater penalty on underestimations than overestimations, promoting models to avoid significant underpredictions, which can be especially critical in predictive tasks where underestimating has more severe implications than overestimating.

# %%
def rmsle(y, y_pred):
    y = np.expm1(y)
    y_pred = np.expm1(y_pred)
    return np.sqrt(mean_squared_log_error( y, y_pred))


rmsle_scorer = make_scorer(rmsle, greater_is_better=False)
tscv = TimeSeriesSplit(n_splits=5)

# %%
columns = ['weather_code','season','is_non_workday']
X_dummies = pd.get_dummies(X_train, columns=columns)
X_dummies = X_dummies.drop(['day_of_week','day_of_month','year','month'],axis=1)

# %% [markdown]
# ### 5.4 Rough model test
#
# The analysis above represents a basic test of three algorithms, specifically excluding the optimization process. The primary aim is to preliminarily assess the performance of the models, with an emphasis on observing their runtime.

# %%
def rough_test():
    names = ["LinearRegression", "Random Forrest", "XGBoost"]
    
    regressors = [
        LinearRegression(),
        RandomForestRegressor(random_state=42),
        XGBRegressor(objective ='reg:squarederror',random_state=42),  
        ]
    
    data_X = [X_dummies,X_train ,X_train ,X_dummies ,X_train ,X_train ]
    reg_columns=['algorithm','score_rmsle_mean','score_std','time']
    reg_performance = pd.DataFrame(columns=reg_columns)
    for name, regressor, X_trains in zip(names, regressors,data_X):
        time_start = time.time()
        cv_results = cross_val_score(regressor, X_trains,y_train, cv=5 ,scoring = rmsle_scorer)
        time_end = round(time.time() - time_start,3)
        mean_score = round(-cv_results.mean(),4)
        std_score = round(cv_results.std(),4)
        t= pd.DataFrame([[name,mean_score,std_score,time_end]],columns = reg_columns)
        reg_performance = pd.concat([reg_performance, t], ignore_index=True)
    return reg_performance
    
reg_performance = rough_test()
reg_performance
# Out:
#           algorithm  score_rmsle_mean  score_std    time
# 0  LinearRegression            0.5028     0.0127   0.056
# 1    Random Forrest            0.0149     0.0191  17.701
# 2           XGBoost            0.0287     0.0179   0.757

# %% [markdown]
# It is evident that the Ordinary Least Squares (OLS) linear regression algorithm executes rapidly. However, its prediction accuracy is significantly lower compared to the Random Forest (RF) and XGBoost algorithms. While RF and XGBoost display similar levels of accuracy, RF operates noticeably slower than XGBoost.

# %% [markdown]
# ### 5.5 Optimization and Cross validation
#
# During the model optimization phase, a grid search technique is employed to systematically explore various parameter combinations. This approach identifies parameters that significantly impact prediction accuracy, enabling appropriate adjustments to model settings.
#
# In the evaluation phase, time series cross-validation is utilized specifically for optimizing a bicycle usage prediction model in London. This method respects the chronological order of data to prevent the premature incorporation of future data in training, thereby eliminating the risk of information leakage.

# %%
linear_model = LinearRegression()
linear_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Noticing that some of the parameter sets are comment and set to a single value. This is to ensure that the code can be executed in a short time.
# The set parameter are the best values run by GridSearchCV.
# If uncomment the parameter sets, please comment or the related lines with a single value list.
# If uncomment all the sets, it might take extremely long to run, at least my Jupyter Lab crashes when I do so.


grid_values = {
    # "learning_rate": [0.001, 0.01, 0.1, 0.3],
    # "n_estimators": [100, 700, 1000, 1200],
    "max_depth": [3, 5, 8, 10],
    "min_child_weight": [1, 2, 3, 4],
    "gamma": [0, 0.1, 0.2, 0.3],
    # 'reg_alpha': [0.1,1,200,500],
    # 'reg_lambda':[1,200,500],
    "learning_rate": [0.01],
    "n_estimators": [1000],
    "reg_alpha": [0.1],
    "reg_lambda": [1],
}

best_values = {
    "learning_rate": 0.01,
    "n_estimators": 1000,
    "max_depth": 5,
    "min_child_weight": 1,
    "gamma": 0,
    "reg_alpha": 0.1,
    "reg_lambda": 1,
}

grid_xgb = GridSearchCV(
    XGBRegressor(objective="reg:squarederror", eval_metric="rmse", random_state=42),
    n_jobs=-1,
    param_grid=grid_values,
    cv=tscv,
    scoring=rmsle_scorer,
)
grid_xgb.fit(X_train, y_train)
xgb_cv = pd.DataFrame(grid_xgb.cv_results_)

# print(xgb_cv[xgb_cv["rank_test_score"] < 4])
print("Best parameters for XGBoost:")
print(grid_xgb.best_estimator_.get_params())
# Out:
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# /opt/conda/lib/python3.11/site-packages/xgboost/data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
# Noticing that some of the parameter sets are comment and set to a single value. This is to ensure that the code can be executed in a short time.
# The set parameter are the best values run by GridSearchCV.
# If uncomment the parameter sets, please comment or the related lines with a single value list.
# If uncomment all the sets, it might take extremely long to run, my Jupyter Lab does not crash this time, but takes about 20mins.

grid_values_rf = {
    # "n_estimators": [10, 100, 500, 750, 1000, 1200],
    "max_depth": [5, 7, 8, 9],
    "min_samples_leaf": [5, 10, 25, 50],
    # "max_features": ["auto", "sqrt"],
    "n_estimators": [500],
    "max_features": ["sqrt"],
}

best_values_rf = {
    "n_estimators": 500,
    "max_depth": 9,
    "min_samples_leaf": 5,
    "max_features": "sqrt",
}

grid_rf = GridSearchCV(
    RandomForestRegressor(random_state=42),
    param_grid=grid_values_rf,
    cv=tscv,
    scoring=rmsle_scorer,
)
grid_rf.fit(X_train, y_train)
rf_cv = pd.DataFrame(grid_rf.cv_results_)

# print(rf_cv[xgb_cv["rank_test_score"] < 4])
print("Best parameters for Random Forest:")
print(grid_rf.best_estimator_.get_params())
# Out:
# Best parameters for Random Forest:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 9, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 5, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 500, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}

# %%
def collect_scores(model,X_train,y_train):
    prediction_train = np.expm1((model.predict(X_train).clip(min=0)))
    y_train = np.expm1(y_train)
    rms_error = np.sqrt(mean_squared_error(y_train, prediction_train))
    mean_abs_error = mean_absolute_error(y_train, prediction_train)
    r2 = r2_score(y_train, prediction_train)
    rmsle = np.sqrt(mean_squared_log_error(y_train, prediction_train))
    return {
        "Model": model.__class__.__name__,
        "RMSE": rms_error,
        "MAE": mean_abs_error,
        "R^2": r2,
        "RMSLE": rmsle
    }

results = []
results.append(collect_scores(linear_model, X_test, y_test))
results.append(collect_scores(grid_rf.best_estimator_, X_test, y_test))
results.append(collect_scores(grid_xgb.best_estimator_, X_test, y_test))

results_df = pd.DataFrame(results)
results_df
# Out:
#                    Model         RMSE         MAE       R^2     RMSLE
# 0       LinearRegression  1463.008879  558.942898 -0.573242  0.488096
# 1  RandomForestRegressor   229.471554  114.911424  0.961296  0.128808
# 2           XGBRegressor    44.560510    9.706377  0.998541  0.035849

# %% [markdown]
# Table above is a simple present to the result, more detailed analysis in the next chapter.

# %% [markdown]
# ### 5.6 Residual Analysis
#
# The analysis consists of following parts:
# .
# tion.

# %% [markdown]
# ### 5.6 Residual Analysis
#
# The analysis consists of following parts:
#
# * Normality Test: The D’Agostino’s K² test was conducted to check whether the residuals conform to a normal distribution.
# * Residual Statistics: The mean, standard deviation, skewness, and kurtosis of the residuals were calculated.
# * Scatter Plot: Displays the relationship between test values and residuals, checking if residuals systematically change with predicted values.
# * Histogram: Used to evaluate the distribution of residuals and observe if they approximate a normal distribution.
# * Q-Q Plot: Further verifies the normality of the residual distribution.

# %%
def residual_plot(y_test, y_predicted,main_title):
    res =  np.expm1(y_test) - np.expm1(y_predicted)
    fig, axs = plt.subplots(1,3, figsize=(25, 5))
    stat, p = stats.normaltest(res)
    print("Performing a D’Agostino’s K^2 Test for a normal distribution of residuals.")
    print("H0 = The distribution is Gaussian.P value to reject H0 is p= 0.05 = 5%")
    print('Statistics=%.3f, p=%.5f' % (stat, p))
    
    alpha = 0.05
    if p > alpha:
        print("failed to reject H0 (H0 = The distribution is Gaussian).Can't accept any hypothesis. ")
    else:
        print('The distribution does not look Gaussian (H0 is rejected)')
    
    plt.suptitle(f'{main_title} ; mean_residual =  {res.mean():.1f}, std= {res.std():.1f},  skew =  {res.skew():.4f} , kurtosis= {res.kurtosis():.2f}'  )
    axs[0].title.set_text('Scatter Plot y_test vs residuals(true-predicted)')
    axs[0].scatter(np.expm1(y_test),res)
    axs[1].title.set_text('Histogram of residuals')
    sns.distplot(res, fit=norm, ax = axs[1]);
    axs[2].title.set_text('Q-Q plot')
    sm.qqplot(res, stats.t, distargs=(4,),line = 's', ax=axs[2])
    plt.show()

residual_plot(y_test, linear_model.predict(X_test) ,"Residual plots of OLS predictions")
residual_plot(y_test, grid_rf.best_estimator_.predict(X_test) ,"Residual plots of RandomForrest predictions")
residual_plot(y_test, grid_xgb.best_estimator_.predict(X_test) ,"Residual plots of XGBoost predictions")
# Out:
# Performing a D’Agostino’s K^2 Test for a normal distribution of residuals.
# H0 = The distribution is Gaussian.P value to reject H0 is p= 0.05 = 5%
# Statistics=4908.912, p=0.00000
# The distribution does not look Gaussian (H0 is rejected)
# /tmp/ipykernel_1900/2786681459.py:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(res, fit=norm, ax = axs[1]);
# Performing a D’Agostino’s K^2 Test for a normal distribution of residuals.
# H0 = The distribution is Gaussian.P value to reject H0 is p= 0.05 = 5%
# Statistics=3611.731, p=0.00000
# The distribution does not look Gaussian (H0 is rejected)
# ...

# %% [markdown]
# There are some outliers that are visible in the scatter plot and histogram, but most of the quantity of residuals are near 0. The shape of residuals on the scatter plot is affected by the RMSLE metric. Underestimates have greater penalty than overestimates and the scoring is performed on percentage error - huge difference on high value predictions are not so much penalized. This metric reduces the effect of errors generated by outliers in dataset.
#
# The residuals of all three models are not normally distributed.
#
# The Random forest residuals have positive skew and positive mean. Also with increasing of the predicting variable the residuals also increase, but only in positive direction. The variance of the residuals is increasing and there is a positive systematic error with increasing of the predicted variable.
#
# The residuals of XGBoost looks better in this terms, still there are outliers, but the mean of the residuals is closer to zero, Q-Q plot is better fitted than Random Forest.

# %% [markdown]
# ## 6. Results
#
# Ordinary Least Squares (OLS), Random Forest, and XGBoost—are compared using the following performance metrics:
# * Root Mean Squared Error (RMSE)
# * Mean Absolute Error (MAE)
# * Coefficient of Determination (R²)
# * Root Mean Squared Logarithmic Error (RMSLE)

# %%
plt.figure(figsize=(12, 8))

for i, metric in enumerate(['RMSE', 'MAE', 'R^2', 'RMSLE'], start=1):
    plt.subplot(2, 2, i)
    sns.barplot(x='Model', y=metric, data=results_df, palette='viridis')
    plt.title(f'Comparison of Models by {metric}')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
def print_scores(model,X_train,y_train):
    print("Model parameters ", model.__class__.__name__)
    prediction_train = np.expm1((model.predict(X_train).clip(min=0)))
    y_train = np.expm1(y_train)
    print("Root Mean Squared Error: " + str(np.sqrt(mean_squared_error(y_train, prediction_train))))
    print("Mean Absolute Error: " + str(mean_absolute_error(y_train, prediction_train)))
    print("R^2 Coefficient of Determination: " + str(r2_score(y_train, prediction_train)))
    print('RMSLE:', np.sqrt(mean_squared_log_error(y_train, prediction_train)))

print('---------OLS Model evaluation on train set---------------')
print_scores(linear_model,X_train,y_train)
print('\n--------OLS Model evaluation on test set---------------')
print_scores(linear_model,X_test,y_test)

print('\n---------RF Model evaluation on train set---------------')
print_scores(grid_rf.best_estimator_,X_train,y_train)
print('\n--------RF Model evaluation on test set---------------')
print_scores(grid_rf.best_estimator_,X_test,y_test)

print('---------XGB Model evaluation on train set---------------')
print_scores(grid_xgb.best_estimator_,X_train,y_train)
print('\n--------XGB Model evaluation on test set---------------')
print_scores(grid_xgb.best_estimator_,X_test,y_test)
# Out:
# ---------OLS Model evaluation on train set---------------
# Model parameters  LinearRegression
# Root Mean Squared Error: 1877.56051481498
# Mean Absolute Error: 394.3796595091267
# R^2 Coefficient of Determination: -2.23773481721594
# RMSLE: 0.49066529655526436
#
# --------OLS Model evaluation on test set---------------
# Model parameters  LinearRegression
# Root Mean Squared Error: 1463.0088789345864
# Mean Absolute Error: 558.9428983285558
# R^2 Coefficient of Determination: -0.5732421871304163
# RMSLE: 0.48809624499077225
#
# ---------RF Model evaluation on train set---------------
# Model parameters  RandomForestRegressor
# Root Mean Squared Error: 155.69473841144048
# Mean Absolute Error: 69.63819780278375
# R^2 Coefficient of Determination: 0.9777360990646458
# RMSLE: 0.10832473102729821
#
# --------RF Model evaluation on test set---------------
# Model parameters  RandomForestRegressor
# Root Mean Squared Error: 229.47155432443722
# Mean Absolute Error: 114.91142380071456
# ...

# %% [markdown]
# 1. OLS:
#
# Exhibits relatively high RMSE and RMSLE, indicating potential high variance issues when handling this dataset.
#
# The low R² value suggests weak explanatory power of the model over the data.
#
# 2. RF:
#
# Generally performs better than OLS across all metrics, particularly in RMSLE and R², which shows more robust handling of outliers and higher prediction accuracy.
#
# Lower RMSE and MAE values indicate smaller deviations between predicted and actual values.
#
# 3. XGB:
#
# Typically shows the best performance across all metrics, especially in RMSLE and R², demonstrating high fitting capability to the data.
#
# Its low RMSE and MAE values further validate its superiority in prediction accuracy.

# %% [markdown]
# ## 7. Conlusion and Disscussion
# ### 7.1 Result Analysis
# As the results part mentioned, XGBoost outperforms the other two models, making it particularly suitable for prediction tasks involving complex patterns and nonlinear relationships. Although Random Forest does not perform as well as XGBoost in some metrics, it still surpasses OLS, showing better robustness and lower prediction errors. Ordinary Least Squares may not be the best choice for challenging datasets due to its larger prediction errors and weaker model interpretability. These analytical results can provide strong support for selecting the appropriate prediction model.
#
# ### 7.2 Conclusion
# In the applications of predicting London sharing bike hourly usage, the research's result provides a direct comparison of model performance and indicates the suitability of each model under specific data characteristics. The finding can be utilized in :
# 1. Enhanced Decision Support Quality: By using the best-performing XGBoost model, decision-makers can rely on more accurate predictions to formulate policies or optimize resource allocation, such as adjusting the distribution and maintenance schedules of bikes.
# 2. Optimized Operational Efficiency: The Random Forest and XGBoost models demonstrated robust handling of outliers, which helps maintain service quality and operational efficiency under dynamically changing market conditions.
# 3. Cost Reduction: Accurate demand prediction allows operators to minimize over-investment and resource wastage, while improving user satisfaction.
#
# ### 7.3 Future Work
# 1. Continued Exploration of Data and Feature Engineering: Further mining and integrating additional data sources, such as weather, holidays, and city events, could enhance model predictive accuracy. Exploring more advanced feature engineering techniques, such as automatic feature selection and generation, might reveal deeper data associations and patterns.
# 2.
# Deepened Model Optimization and Tuning: Although XGBoost performs well, more systematic hyperparameter tuning and the use of more complex ensemble methods, such as Stacking or Blending models, could further improve performance.3.
# Implementation of More Complex Models: Given the characteristics of time series, exploring deep learning models like LSTM (Long Short-Term Memory networks) could offer a more refined solution for capturing time dependencies and nonlinear relationships.

# %% [markdown]
# ## 7. Conlusion and Disscussion
# ### 7.1 Result Analysis
# As the results part mentioned, XGBoost outperforms the other two models, making it particularly suitable for prediction tasks involving complex patterns and nonlinear relationships. Although Random Forest does not perform as well as XGBoost in some metrics, it still surpasses OLS, showing better robustness and lower prediction errors. Ordinary Least Squares may not be the best choice for challenging datasets due to its larger prediction errors and weaker model interpretability. These analytical results can provide strong support for selecting the appropriate prediction model.
#
# ### 7.2 Conclusion
# In the applications of predicting London sharing bike hourly usage, the research's result provides a direct comparison of model performance and indicates the suitability of each model under specific data characteristics. The finding can be utilized in :
# 1. Enhanced Decision Support Quality: By using the best-performing XGBoost model, decision-makers can rely on more accurate predictions to formulate policies or optimize resource allocation, such as adjusting the distribution and maintenance schedules of bikes.
# 2. Optimized Operational Efficiency: The Random Forest and XGBoost models demonstrated robust handling of outliers, which helps maintain service quality and operational efficiency under dynamically changing market conditions.
# 3. Cost Reduction: Accurate demand prediction allows operators to minimize over-investment and resource wastage, while improving user satisfaction.
#
# ### 7.3 Future Work
# 1. Continued Exploration of Data and Feature Engineering: Further mining and integrating additional data sources, such as weather, holidays, and city events, could enhance model predictive accuracy. Exploring more advanced feature engineering techniques, such as automatic feature selection and generation, might reveal deeper data associations and patterns.
# 2. Deepened Model Optimization and Tuning: Although XGBoost performs well, more systematic hyperparameter tuning and the use of more complex ensemble methods, such as Stacking or Blending models, could further improve performance.
# 3. Implementation of More Complex Models: Given the characteristics of time series, exploring deep learning models like LSTM (Long Short-Term Memory networks) could offer a more refined solution for capturing time dependencies and nonlinear relationships.

# %% [markdown]
# ## 8. References
#
# Shaheen, S. A., Cohen, A. P., & Martin, E. W. (2013). ‘Public Bikesharing in North America: Early Operator Understanding and Emerging Trends’, *Transportation Research Record*, 2387(1), pp.83-92. doi: https://doi.org/10.3141/2387-10
#
# Craig Bullock, Finbarr Brereton and Sive Bailey (2017). ‘The economic contribution of public bike-share to the sustainability and efficient functioning of cities’, *Sustainable Cities and Society*, 28, pp.76-87. doi: https://doi.org/10.1016/j.scs.2016.08.024.
#
# Rixey, R. A. (2013). ‘Station-Level Forecasting of Bikesharing Ridership: Station Network Effects in Three U.S. Systems’, *Transportation Research Record*, 2387(1), pp.46-55. doi: https://doi.org/10.3141/2387-06
#
# Ahmadreza Faghih-Imani, Naveen Eluru, Ahmed M. El-Geneidy, Michael Rabbat, Usama Haq (2014). ‘How land-use and urban form impact bicycle flows: evidence from the bicycle-sharing system (BIXI) in Montreal’, *Journal of Transport Geography*, 41, pp.306-314. doi: https://doi.org/10.1016/j.jtrangeo.2014.01.013.
#
# Gu, K. & Lin, Y. (2023) ‘Prediction for bike-sharing demand in London using multiple linear regression and random forest,’ *SPIE* pp. 128031I-128031I – 6.
#
# Schimohr, K. et al. (2023) ‘Prediction of Bike‐sharing Trip Counts: Comparing Parametric Spatial Regression Models to a Geographically Weighted XGBoost Algorithm.’ *Geographical analysis* 55 (4), pp. 651–684.
